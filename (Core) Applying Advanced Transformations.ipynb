# %% [markdown]
# # Applying Advanced Transformations (Core)

# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json
pd.set_option('display.max_column', None)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Hero Info

# %%
## Load in csv.gz
info = pd.read_csv('Data/superhero_info.csv')
info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
info.duplicated().sum()
# Out:
# 0

# %%
info.isna().sum()
# Out:
# Hero|Publisher    0
# Gender            0
# Race              0
# Alignment         0
# Hair color        0
# Eye color         0
# Skin color        0
# Measurements      0
# dtype: int64

# %% [markdown]
# ### Split Hero and Publisher to separate columns

# %%
## adding expand=True
info['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
info[['Hero_names','Publisher']] = info['Hero|Publisher'].str.split('|',expand=True)
info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#    Hero_names          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
## drop the original column 
info = info.drop(columns=['Hero|Publisher'])
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements  Hero_names          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %% [markdown]
# ### Split Height and Weight into separate columns

# %%
## use .apply pd.Series to convert a dict to columns
info['Measurements'].apply(pd.Series)
# Out:
#                                                 0
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# ..                                            ...
# 458   {'Height': '183.0 cm', 'Weight': '83.0 kg'}
# 459   {'Height': '165.0 cm', 'Weight': '52.0 kg'}
# 460    {'Height': '66.0 cm', 'Weight': '17.0 kg'}
# 461   {'Height': '170.0 cm', 'Weight': '57.0 kg'}
# 462   {'Height': '185.0 cm', 'Weight': '81.0 kg'}
#
# [463 rows x 1 columns]

# %%
## replace ' with " (entire column)
info['Measurements'] = info['Measurements'].str.replace("'", '"')
## apply json.loads
info['Measurements'] = info['Measurements'].apply(json.loads)

# %%
## use .apply pd.Series to convert a dict to columns
info['Measurements'].apply(pd.Series)
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
## Concatenate the 2 new columns and drop the original.
info = pd.concat([info, info['Measurements'].apply(pd.Series)], axis = 1)
#df = df.drop(columns = 'coordinates')
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements  Hero_names  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
## drop the original column 
info = info.drop(columns=['Measurements'])
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  Hero_names  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
## adding expand=True
info['Height'].str.split(' ',expand=True)
# Out:
#          0   1
# 0    203.0  cm
# 1    191.0  cm
# 2    185.0  cm
# 3    203.0  cm
# 4    193.0  cm
# ..     ...  ..
# 458  183.0  cm
# 459  165.0  cm
# 460   66.0  cm
# 461  170.0  cm
# 462  185.0  cm
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
info[['Height_cm','cm']] = info['Height'].str.split(' ',expand=True)
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  Hero_names  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight Height_cm  cm
# 0      Marvel Comics  203.0 cm  441.0 kg     203.0  cm
# 1  Dark Horse Comics  191.0 cm   65.0 kg     191.0  cm

# %%
## drop the original column 
info = info.drop(columns=['Height', 'cm'])
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  Hero_names  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Weight Height_cm
# 0      Marvel Comics  441.0 kg     203.0
# 1  Dark Horse Comics   65.0 kg     191.0

# %%
## adding expand=True
info['Weight'].str.split(' ',expand=True)
# Out:
#          0   1
# 0    441.0  kg
# 1     65.0  kg
# 2     90.0  kg
# 3    441.0  kg
# 4    122.0  kg
# ..     ...  ..
# 458   83.0  kg
# 459   52.0  kg
# 460   17.0  kg
# 461   57.0  kg
# 462   81.0  kg
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
info[['Weight_kg','kg']] = info['Weight'].str.split(' ',expand=True)
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  Hero_names  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Weight Height_cm Weight_kg  kg
# 0      Marvel Comics  441.0 kg     203.0     441.0  kg
# 1  Dark Horse Comics   65.0 kg     191.0      65.0  kg

# %%
info = info.drop(columns = ['Weight', 'kg'])
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  Hero_names  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height_cm Weight_kg
# 0      Marvel Comics     203.0     441.0
# 1  Dark Horse Comics     191.0      65.0

# %%
datatypes = info.dtypes['Weight_kg']
datatypes
# Out:
# dtype('O')

# %%
# convert just columns Weight_kg and Height_cm
info[["Weight_kg","Height_cm"]] = info[["Weight_kg","Height_cm"]].apply(pd.to_numeric)
info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color       Hero_names          Publisher  Height_cm  Weight_kg
# ...

# %%
datatypes = info.dtypes['Weight_kg']
datatypes
# Out:
# dtype('float64')

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero_names  463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height_cm   463 non-null    float64
#  9   Weight_kg   463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
## save data for next lesson
info.to_csv('advanced_hero_info.csv', index=False)

# %% [markdown]
# ### Powers

# %%
power = pd.read_csv('Data/superhero_powers.csv')
power.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
power = power.rename(columns ={'hero_names':'Hero_names'})
power.head()
# Out:
#     Hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
## showing the lists are really strings
power.loc[2,'Powers']
# Out:
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
## adding expand=True
power['power_split'] = power['Powers'].str.split(',')

# %%
## exploding the column of lists
exploded = power.explode('power_split')
exploded.head()
# Out:
#   Hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#            power_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['power_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
    power[col] = power['Powers'].str.contains(col)
power.head()
# Out:
#     Hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                          power_split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  \
# ...

# %%
# drop transactions clumns
power_f = power.drop(columns=['Powers','power_split'])
power_f.head()
# Out:
#     Hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    Cold Resistance  Underwater breathing  Marksmanship  Weapons Master  \
# ...

# %%
## save data for next lesson
power_f.to_csv('advanced_power.csv', index=False)

# %%
new_df = pd.concat([info, power_f], axis=1)
new_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#       Hero_names          Publisher  Height_cm  Weight_kg   Hero_names  \
# 0         A-Bomb      Marvel Comics      203.0      441.0      3-D Man
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0       A-Bomb
# 2       Abin Sur          DC Comics      185.0       90.0   Abe Sapien
# 3    Abomination      Marvel Comics      203.0      441.0     Abin Sur
# 4  Absorbing Man      Marvel Comics      193.0      122.0  Abomination
#
#    Agility  Super Strength  Stamina  Super Speed  Accelerated Healing  \
# ...

# %%
## save data for next lesson
new_df.to_csv('advanced_hero_power.to_csv', index=False)

# %% [markdown]
# ### 1. Compare the average weight of super powers who have Super Speed to those who do not.

# %%
new_df.groupby(['Super Speed'])['Weight_kg'].mean()
# Out:
# Super Speed
# False    113.705479
# True     113.391813
# Name: Weight_kg, dtype: float64

# %% [markdown]
# ### There isn't any deference in weight of heros with or without super speed.

# %% [markdown]
# ### 2. What is the average height of heroes for each publisher?

# %%
new_df.groupby(['Publisher'])['Height_cm'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height_cm, dtype: float64
